# %%
#https://ndcbe.github.io/cbe67701-uncertainty-quantification/07.02-Latin-Hypercube-sampling.html

from scipy.stats import qmc
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(13) #randomseed
d = 2 #Dimensions
sampler = qmc.LatinHypercube(d=d, seed=13) #Hypercube
sample = sampler.random(n=40) #Number of samples
l_bounds = np.array([3, 1.6]) #Upper Boundaries
u_bounds = np.array([13, 2.7]) #Lower Boundaries
sample_scaled = qmc.scale(sample, l_bounds, u_bounds) #Samples Scaled
print(sample_scaled) #Print the samples

plt.figure(figsize=(6, 6))
plt.scatter(sample_scaled[:, 0], sample_scaled[:, 1], c='grey', marker='x', edgecolors='c')
plt.title('40 Latin Hypercube Samples')
plt.xlabel('Sac Diameter')
plt.ylabel('Vessel Diameter')
plt.grid(True)
plt.show()
# Out:
# [[ 4.5338006   1.71397918]
#  [ 6.29724415  2.58281023]
#  [12.73070014  1.98647219]
#  [ 8.84655208  2.56242765]
#  [12.27239821  2.3429179 ]
#  [ 7.42842585  2.15512432]
#  [ 8.72939801  2.4679473 ]
#  [11.04557406  2.63375983]
#  [ 3.37056257  1.8717814 ]
#  [ 4.79649837  2.41130865]
#  [ 6.1879302   2.67864113]
#  [ 5.00519293  1.88769556]
#  [ 5.31571244  1.95769908]
#  [ 6.74246813  1.74852811]
#  [ 7.50817618  2.50427324]
#  [ 6.94422463  1.61236872]
#  [11.56941817  2.24479931]
#  [11.36307455  2.14858268]
#  [ 9.56519257  2.30618071]
#  [ 7.98150953  1.65614212]
#  [10.33508217  2.08246597]
#  [ 3.81683713  1.94435802]
#  [ 8.46881967  2.60087405]
#  [11.81326589  2.21203596]
#  [ 4.11210815  1.76696648]
#  [ 9.76357186  1.79594108]
#  [10.15708909  1.64763632]
#  [ 5.867547    2.51700647]
#  [ 9.20985168  2.02461473]
#  [ 9.39026294  2.28745422]
#  [12.14529255  1.83650278]
#  [ 3.50915269  2.20350084]
#  [ 4.26786349  1.90502121]
#  [10.60004994  2.3923512 ]
#  [ 8.05217392  2.33805815]
#  [10.9198399   2.65417337]
#  [ 3.14369117  2.10982456]
#  [ 5.67421069  2.45147597]
#  [12.90980797  1.68726788]
#  [ 7.04245957  2.06527079]]
# C:\Users\ismai\AppData\Local\Temp\ipykernel_21700\4026272673.py:15: UserWarning: You passed a edgecolor/edgecolors ('c') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(sample_scaled[:, 0], sample_scaled[:, 1], c='grey', marker='x', edgecolors='c')
